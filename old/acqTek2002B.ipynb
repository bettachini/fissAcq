# %%
# %pylab inline
# coding=utf-8

import tek3 as tek3

test = tek3.TekScope("/dev/usbtmc0")

import time

# refresca de lo importado cada vez que se hace ejecución
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib
# TEKTRONIX,TDS 2002B,C101891,CF:91.1CT FV:v22.11

# %% [markdown]
# # Registro automático de picos

# %%
def init(inst=test): # CFP-35 con electrónica Luis modernizada 151016
    inst.write('INITIATE_CLEAR')
    inst.write('HEADER OFF')
    inst.set_data_encoding('RIBinary')
    inst.write('ACQuire:MODe SAMple') # test.write('ACQuire:MODe PEAKdetect') lo descarto pues manual dice que puede verse mas ruidoso  
    inst.write('ACQUIRE:STOPAFTER SEQUENCE')
    inst.write('ACQuire:STATE RUN')
    inst.write('CH1:SCAle 0.01') # FLUC
    inst.write('CH1:POSition -2.0')
    inst.write('CH2:SCAle 1.0') # AMC
    inst.write('CH2:POSition -1.96')
    inst.horizontal_main_scale(2.5E-7)
    inst.horizontal_main_position(2.0E-8)
    
    
# Viejo
# def init(inst=test):
#     inst.write('INITIATE_CLEAR')
#     inst.set_data_encoding('RIBinary')
#     inst.write('ACQuire:MODe SAMple') # test.write('ACQuire:MODe PEAKdetect') lo descarto pues manual dice que puede verse mas ruidoso  
#     inst.write('ACQUIRE:STOPAFTER SEQUENCE')
#     inst.write('ACQuire:STATE RUN')
#     inst.write('CH1:POSition -2')
#     inst.write('CH1:SCAle 5E-3')
#     inst.write('CH2:POSition -3')
#     # inst.write('CH2:SCAle 1')
#     inst.write('CH2:SCAle 0.5') # Para detector Centronic FC-165 y CFC-35 desde 150601
#     inst.horizontal_main_position(0)
#     inst.horizontal_main_scale(2.5E-7)
    
    
def escalas(inst=test):
    # obtener una vez los límites verticales del canal
    pos1 = inst.get_channel_position(1)
    scale1 = inst.get_channel_scale(1)
    pos2 = inst.get_channel_position(2)
    scale2 = inst.get_channel_scale(2)
    return pos1, scale1, pos2, scale2


def flName(camara, tipo, N):
    filePath= './data/'
    fileDate= time.strftime('%y%m%d')
    fileCamara= camara # 'n' nuestra = Campbelliana
    fileN= N
    fileExt= '.npy'
    fileType= tipo
    fileName= filePath+ fileType+ fileDate + fileCamara+ ('{:02n}'.format(fileN))+ fileExt
    return fileName


def param(camara='CFP-35'):
    '''
    Grabo parámetros de la medición
    '''
    test.load_setup() # Obtiene parámetros del osciloscopio
    sets= test.dico
    [pos1, scale1, pos2, scale2]= escalas()
    sets['POSITION1']= pos1
    sets['SCALE1']= scale1
    sets['POSITION2']= pos2
    sets['SCALE2']= scale2
    sets['ELECTRONICA']= 'Luis'
    sets['FUENTE']= 'Canberra 3002'
#     sets['FUENTE']= 'Canberra 3002'
    sets['HV']= '400' # [V] diferencia potencial fuente
    sets['CAMARA']= camara
    sets['PRESION_AR']= '2.725' # [kgf/cm^2] (rel) 150528
    sets['PRESION_N2']= '0.075' # [kgf/cm^2] (rel)  150528
    sets['ESPECTRO']= 'x' # archivo de espectro mas reciente

    return sets


def paramSave(N, camara='CFP-25'):
    '''
    Grabo parámetros de la medición
    '''
    sets= param(camara)

    save(flName(camara, 'sets', N), sets)
    
    
def eins(channel):
    ''' 
    Returns single channel as horizontal array 
    '''
    test.set_data_source(channel)
    Y= float16(test.bin_read())
    return Y


def readBuff2(self):
    try:
        return self.ask('CURVE?')
    except TimeoutError:
        print('Probably requested channel has no data')
        raise
        
        
def zwei():
    '''
    Returns both channels as horizontal array
    '''
    Y1= eins(1)
    Y2= eins(2)
    Meas2= np.vstack([Y1, Y2])
    return Meas2


def single():
    '''
    Queries both channels, restarts acquistion
    '''
    test.start_acq()
    Meas2= zwei()
    return Meas2


def darstellungNurZwei(T, Meas2, sav= None):
    '''
    T: times vector
    Meas2: Both channels 2D array
    sav: plot filename (eps)
    '''
        
    fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
    fig.set_size_inches(10,8)
    fig.subplots_adjust(hspace=0.000)

    ax0.plot(T, Meas2[0,:], 'y')
    # Make the y-axis label and tick labels match the line color.
    ax0.set_ylabel('ch 1 [V]', color='y')
    ax0.grid(True)

    ax1.plot(T, Meas2[1,:], 'c')
    ax1.set_ylabel('ch 2 [V]', color='c')
    ax1.set_xlabel('tiempo [s]')
    ax1.grid(True)
    
    if (sav):
        plt.savefig('./data/'+ sav+ '.eps')
    else:
        plt.show()
        
        
def darstellungNurZwei(T, Meas2, sav= None):
    '''
    T: times vector
    Meas2: Both channels 2D array
    sav: plot filename (eps)
    '''
        
    fig, (ax0, ax1) = plt.subplots(nrows=2, sharex=True)
    fig.set_size_inches(10,8)
    fig.subplots_adjust(hspace=0.000)

    ax0.plot(T, Meas2[0,:], 'y')
    # Make the y-axis label and tick labels match the line color.
    ax0.set_ylabel('ch 1 [V]', color='y')
    ax0.grid(True)

    ax1.plot(T, Meas2[1,:], 'c')
    ax1.set_ylabel('ch 2 [V]', color='c')
    ax1.set_xlabel('tiempo [s]')
    ax1.grid(True)
    
    if (sav):
        plt.savefig('./data/'+ sav+ '.eps')
    else:
        plt.show()
        
        
def acqDartellung(nombre, inst=test, graf=False):
    zeit= tek3.TekScope.Xaxis(inst)
    data= zeit
    print('\n')
    for count in range(nombre): #
        while(test.textAsk('BUSY?')=='1'):
            time.sleep(.5)
        M2= single()
        data= np.vstack([data,M2])
        if (graf):
            darstellungNurZwei(zeit, M2)
        print('\rN= '+ str(count+ 1), end=' ')
    print('\n')
    return data


def prom(data, prop):
    '''
    (array, float) -> array
    
    Obtiene el promedio de la primer fracción prop de ambos canales de todas las mediciones en data
    grProm[0]: ch1, grProm[1]: ch2

    '''
    messungenZahl= data.shape
    erstePunkten= int(messungenZahl[1]* prop)
    prom= np.zeros([int((messungenZahl[0]- 1)/ 2), 2])
    for i in range(1, messungenZahl[0], 2):
        ix= int((i-1)/2)
        prom[ix,0]= (data[i][0:erstePunkten-1]).mean()
        prom[ix,1]= (data[i+1][0:erstePunkten-1]).mean()
    grProm= np.array([ (prom[:,0]).mean(), (prom[:,1]).mean() ])
    return grProm


class archie:
    """Nombre archivo - NO FUNCA AUN, NO PUEDO VARIAR EXTERNAMENTE tipo"""

    def __init__(self, tipo, N, camara):
        """ (archie, int, str, str, str) -> NoneType

        Un nombre de archivo con ruta, cámara, fecha y número 

        >>> archie = CashRegister(5, 5, 5, 5, 5)
        >>> archie.N
        '5'
        >>> archie.camara
        'n'
        >>> archie.path
        './data/'
        >>> register.date
        '150430'
        """
        self.tipo= tipo
        self.N=('{:02n}'.format(N))
        self.camara = camara
        self.path = './data/'
        self.date = time.strftime('%y%m%d')
        self.ext= '.npy'
        self.fileName= self.tipo+ self.date+ self.camara+ self.N+ self.ext

# %% [markdown]
# # Lectura rápida, graba ints comprimidos

# %%
def ptsAdq():
    # correr una vez para obtener parámetros del buffer
    buff2 = readBuff2(test) # esta bien la herencia?
    dataPointsCharacters= int(buff2[1:2])
    dataOffset= 2+ dataPointsCharacters
    return (int(buff2[2:2+ dataPointsCharacters])), dataOffset # número de lecturas en cada adquisición


def rapi(dataCount, dataOffset):
    test.start_acq()
    while(test.textAsk('BUSY?')=='1'):
        time.sleep(1E-3)
    # return (np.frombuffer(readBuff2(test), dtype = np.dtype('int8').newbyteorder('<'), count= dataCount, offset= dataOffset) )  
    buff2 = readBuff2(test) # esta bien la herencia?
    return ( np.frombuffer(buff2, dtype = np.dtype('int8').newbyteorder('<'), count= dataCount, offset= dataOffset) )


def lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial):
    # la lectura en sí
    ch1= np.empty([adquisiciones,puntosAdquisicion], dtype ='int8')
    ch2= np.empty([adquisiciones,puntosAdquisicion], dtype ='int8')
    zeit= tek3.TekScope.Xaxis(test) # zeit
    for medicion in range(adquisiciones):
        print('\rmedición '+ str(medicion)+ ' de '+ str(adquisiciones), end=' ')
        test.set_data_source(1) # canal 2
        ch1[medicion]= rapi(puntosAdquisicion, dataOffset)
        test.set_data_source(2) # canal 2
        ch2[medicion]= rapi(puntosAdquisicion, dataOffset)
    print('\rmedición '+ str(medicion+ 1)+ ' de '+ str(adquisiciones))
    print('Tiempo transcurrido= {:.1f} min'.format((time.time()- tiempoInicial)/60) ) # tiempo transcurrido en segundos
    return zeit, ch1, ch2


def adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset, trgInicial= 0.6):
    '''
    registra ambos canales en formato de multiples arrays
    '''

    tiempoInicial= time.time()

    # Trigger [NO ESTA TERMINADO]
    # trgInicial= 1.52
    trgPaso= 0.25
    trgFinal= trgInicial
    trg= np.arange(trgInicial, trgFinal+trgPaso, trgPaso)
    test.trigger_source('CH2')
    for trgLevel in trg:
        test.trigger_level(trgLevel)
        nivelTrigger= test.trigger_level()
        print('El nivel de trigger es '+ str(nivelTrigger)+ 'V')

    # ch2 =lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial)
    [zeit, ch1, ch2]= lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial)

    # graba    
    np.savez_compressed(flName(descripcionDetector, descripcionArchivo, medicionDia), settings=settings, zeit=zeit, ch1=ch1, ch2=ch2)

# %% [markdown]
# # Adquisición con electrónica Luis

# %%
# CÁMARA CFP-35
tipoMedicion= 'luis'

# secuencia
if (tipoMedicion=='luis'):
    init()
elif(tipoMedicion=='pre'):
    initPre()
else:
    print('¿Cuis?')
settings= param()

adquisiciones= 128 # número de lecturas

descripcionDetector= 'z' # experimental, n usual
descripcionArchivo= 'acq' # experimental, acq usual

# paramSave(medicionDia, descripcionDetector) # grabo archivo experimental de parametros con offsets y escalas de ambos canales
[puntosAdquisicion, dataOffset] = ptsAdq() # puntos por cada adquisición, headbits en cada adquisición

# trgInicial= 1 # Electrónica modernizada 151016
trgInicial= 1.96 # Electrónica modernizada 151016

for medicionDia in np.arange(1,2): # número de mediciones (a_1 , a_2-1)
    adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset, trgInicial)
#     adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset)
# Out:
# El nivel de trigger es 1.96V
# medición 0 de 128
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-f2bc823a915c> in <module>()
#      23
#      24 for medicionDia in np.arange(1,2): # número de mediciones (a_1 , a_2-1)
# ---> 25     adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset, trgInicial)
#      26 #     adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset)
#
# <ipython-input-4-ded784a4c1bd> in adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset, trgInicial)
#      51
#      52     # ch2 =lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial)
# ---> 53     [zeit, ch1, ch2]= lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial)
#      54
#      55     # graba
#
# <ipython-input-4-ded784a4c1bd> in lectura(adquisiciones, puntosAdquisicion, dataOffset, tiempoInicial)
#      24         print('\rmedición '+ str(medicion)+ ' de '+ str(adquisiciones), end=' ')
#      25         test.set_data_source(1) # canal 2
# ---> 26         ch1[medicion]= rapi(puntosAdquisicion, dataOffset)
#      27         test.set_data_source(2) # canal 2
#      28         ch2[medicion]= rapi(puntosAdquisicion, dataOffset)
#
# <ipython-input-4-ded784a4c1bd> in rapi(dataCount, dataOffset)
#       9 def rapi(dataCount, dataOffset):
#      10     test.start_acq()
# ---> 11     while(test.textAsk('BUSY?')=='1'):
#      12         time.sleep(1E-3)
#      13     # return (np.frombuffer(readBuff2(test), dtype = np.dtype('int8').newbyteorder('<'), count= dataCount, offset= dataOffset) )
#
# /oldhome/vbettachini/documents/cnea/campbell/acquisition/tek3.py in textAsk(self, command)
#      71
#      72     def textAsk(self, command):
# ---> 73         return (self.meas.ask(command) ).decode().rstrip('\n')
#      74
#      75     def reset(self):
#
# /oldhome/vbettachini/documents/cnea/campbell/acquisition/tek3.py in ask(self, command)
#      22     def ask(self, command):
#      23         self.write(command)
# ---> 24         return self.read()
#      25
#      26     def getName(self):
#
# /oldhome/vbettachini/documents/cnea/campbell/acquisition/tek3.py in read(self, length)
#      17
#      18     def read(self, length = 4000):
# ---> 19         return os.read(self.FILE, length)
#      20         # return ((os.read(self.FILE, length)).decode()).rstrip('\n')
#      21
#
# KeyboardInterrupt:

# %% [markdown]
# # CÁMARA DE VUELO (DC-045)

# %%
# CÁMARA DE VUELO (DC-045)
test.write('INITIATE_CLEAR')
test.set_data_encoding('RIBinary')
test.write('ACQuire:MODe SAMple') # test.write('ACQuire:MODe PEAKdetect') lo descarto pues manual dice que puede verse mas ruidoso  
test.write('ACQUIRE:STOPAFTER SEQUENCE')
test.write('ACQuire:STATE RUN')
settings= param()

# adquisiciones= 128 # número de lecturas
adquisiciones= 1280 # número de lecturas
rango = np.arange(1,2)

descripcionDetector= 'z' # experimental, n usual
descripcionArchivo= 'acq' # experimental, acq usual

# paramSave(medicionDia, descripcionDetector) # grabo archivo experimental de parametros con offsets y escalas de ambos canales
[puntosAdquisicion, dataOffset] = ptsAdq() # puntos por cada adquisición, headbits en cada adquisición

trgInicial= 1.1 # [V] nivel trigger canal AMC (2) CÁMARA DE VUELO (DC-045)
# trgInicial= 0.6 # [V] nivel trigger canal AMC (2) CÁMARA CFP-35

for medicionDia in rango : # medición 9 a 11 (dos mediciones)
    adquiere(medicionDia, settings, adquisiciones, descripcionDetector, descripcionArchivo, puntosAdquisicion, dataOffset, trgInicial)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-52854219a038> in <module>()
#       5 test.write('ACQUIRE:STOPAFTER SEQUENCE')
#       6 test.write('ACQuire:STATE RUN')
# ----> 7 settings= param()
#       8
#       9 # adquisiciones= 128 # número de lecturas
#
# <ipython-input-2-7eda54effcca> in param(camara)
#      55     test.load_setup() # Obtiene parámetros del osciloscopio
#      56     sets= test.dico
# ---> 57     [pos1, scale1, pos2, scale2]= escalas()
#      58     sets['POSITION1']= pos1
#      59     sets['SCALE1']= scale1
#
# <ipython-input-2-7eda54effcca> in escalas(inst)
#      31 def escalas(inst=test):
#      32     # obtener una vez los límites verticales del canal
# ---> 33     pos1 = inst.get_channel_position(1)
#      34     scale1 = inst.get_channel_scale(1)
#      35     pos2 = inst.get_channel_position(2)
#
# /oldhome/vbettachini/documents/cnea/campbell/acquisition/tek3.py in get_channel_position(self, channel)
#     330
#     331     def get_channel_position(self, channel):
# --> 332         return float(self.ask('%s:POS?'%self.channel_name(channel)))
#     333
#     334     def get_channel_scale(self, channel):
#
# ValueError: could not convert string to float: b':CH1:POSITION -2.0E0\n'
